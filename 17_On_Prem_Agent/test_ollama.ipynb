# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="deepseek-r1:8b")

# %%
for chunk in llm.stream("What is the 3rd root of 27?"):
    print(chunk.content, end="")
# Out:
# <think>
# To find
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for chunk in llm.stream("What is the 3rd root of 27?"):
#       2     print(chunk.content, end="")
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:499, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     497 input_messages = _normalize_messages(messages)
#     498 run_id = "-".join((_LC_ID_PREFIX, str(run_manager.run_id)))
# --> 499 for chunk in self._stream(input_messages, stop=stop, **kwargs):
#     500     if chunk.message.id is None:
#     501         chunk.message.id = run_id
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/langchain_ollama/chat_models.py:803, in ChatOllama._stream(self, messages, stop, run_manager, **kwargs)
#     796 def _stream(
#     797     self,
#     798     messages: list[BaseMessage],
#    (...)    801     **kwargs: Any,
#     802 ) -> Iterator[ChatGenerationChunk]:
# --> 803     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     804         if run_manager:
#     805             run_manager.on_llm_new_token(
#     806                 chunk.text,
#     807                 verbose=self.verbose,
#     808             )
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/langchain_ollama/chat_models.py:763, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#     756 def _iterate_over_stream(
#     757     self,
#     758     messages: list[BaseMessage],
#     759     stop: Optional[list[str]] = None,
#     760     **kwargs: Any,
#     761 ) -> Iterator[ChatGenerationChunk]:
#     762     is_thinking = False
# --> 763     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     764         if not isinstance(stream_resp, str):
#     765             if stream_resp.get("done") is True:
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/langchain_ollama/chat_models.py:665, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     662 chat_params = self._chat_params(messages, stop, **kwargs)
#     664 if chat_params["stream"]:
# --> 665     yield from self._client.chat(**chat_params)
#     666 else:
#     667     yield self._client.chat(**chat_params)
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/ollama/_client.py:172, in Client._request.<locals>.inner()
#     169   e.response.read()
#     170   raise ResponseError(e.response.text, e.response.status_code) from None
# --> 172 for line in r.iter_lines():
#     173   part = json.loads(line)
#     174   if err := part.get('error'):
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/httpx/_models.py:929, in Response.iter_lines(self)
#     927 decoder = LineDecoder()
#     928 with request_context(request=self._request):
# --> 929     for text in self.iter_text():
#     930         for line in decoder.decode(text):
#     931             yield line
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/httpx/_models.py:916, in Response.iter_text(self, chunk_size)
#     914 chunker = TextChunker(chunk_size=chunk_size)
#     915 with request_context(request=self._request):
# --> 916     for byte_content in self.iter_bytes():
#     917         text_content = decoder.decode(byte_content)
#     918         for chunk in chunker.decode(text_content):
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/httpx/_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/httpx/_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/httpx/_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/AI Projects/AIE6 Class Projects/AIE6/17_On_Prem_Agent/.venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
